# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install sklearn
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.post7.tar.gz (3.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
rev_data  = pd.read_csv('/content/drive/MyDrive/햌톤/game_info_keywords.csv')

m = rev_data['review_num'].quantile(0.0)
print(m)
rev_data = rev_data.loc[rev_data['review_num'] >= m]

c = rev_data['rating'].mean()

def weight_rating(x,m=m, c=c):
    v = x['review_num']
    r = x['rating']

    return (v / (v+m)*r)+(m/(v+m) * c)

rev_data['score'] = rev_data.apply(weight_rating, axis = 1)

counter_vector = CountVectorizer(ngram_range = (1,3))
tfidf = TfidfVectorizer(stop_words='english')

tfidf_matrix_keys = tfidf.fit_transform(rev_data['key_words'])
c_vector_keys = counter_vector.fit_transform(rev_data['key_words'])

tfidf_matrix_genres = tfidf.fit_transform(rev_data['genre'])
c_vector_genres = counter_vector.fit_transform(rev_data['genre'])


similarity_genre_c = cosine_similarity(c_vector_genres, c_vector_genres).argsort()[:,::-1]
similarity_genre_t = cosine_similarity(tfidf_matrix_genres, tfidf_matrix_genres).argsort()[:,::-1]

similarity_key_c = cosine_similarity(c_vector_keys, c_vector_keys).argsort()[:,::-1]
similarity_key_t = cosine_similarity(tfidf_matrix_keys, tfidf_matrix_keys).argsort()[:,::-1]

def recommend_movie_list_gc(rev_data, movie_title, top = 7):
    target_movie_index = rev_data[rev_data['Unnamed: 0'] == movie_title].index.values

    sim_index = similarity_genre_c[target_movie_index, :top].reshape(-1)

    sim_index = sim_index[sim_index != target_movie_index]

    result = rev_data.iloc[sim_index].sort_values('score', ascending = False)[:5]

    return result

def recommend_movie_list_gt(rev_data, movie_title, top = 7):
    target_movie_index = rev_data[rev_data['Unnamed: 0'] == movie_title].index.values

    sim_index = similarity_genre_t[target_movie_index, :top].reshape(-1)

    sim_index = sim_index[sim_index != target_movie_index]

    result = rev_data.iloc[sim_index].sort_values('score', ascending = False)[:5]

    return result

def recommend_movie_list_kc(rev_data, movie_title, top = 7):
    target_movie_index = rev_data[rev_data['Unnamed: 0'] == movie_title].index.values

    sim_index = similarity_key_c[target_movie_index, :top].reshape(-1)

    sim_index = sim_index[sim_index != target_movie_index]

    result = rev_data.iloc[sim_index].sort_values('score', ascending = False)[:5]

    return result

def recommend_movie_list_kt(rev_data, movie_title, top = 7):
    target_movie_index = rev_data[rev_data['Unnamed: 0'] == movie_title].index.values

    sim_index = similarity_key_t[target_movie_index, :top].reshape(-1)

    sim_index = sim_index[sim_index != target_movie_index]

    result = rev_data.iloc[sim_index].sort_values('score', ascending = False)[:5]

    return result
# Out:
# 545.0

# %%
recommend_movie_list_gc(rev_data, movie_title = '오목')
# Out:
#    Unnamed: 0  genre  rating  review_num  \
# 56     애니팡 맞고  board     3.9      128000
# 51      퍼즐쓰리고  board     3.9       23700
# 53     애니팡 포커  board     3.8       48100
# 57       맞고의신  board     3.6       33700
# 59         장기  board     3.5       57400
#
#                                                   url  \
# 56  https://play.google.com/store/apps/details?id=...
# 51  https://play.google.com/store/apps/details?id=...
# 53  https://play.google.com/store/apps/details?id=...
# 57  https://play.google.com/store/apps/details?id=...
# 59  https://play.google.com/store/apps/details?id=...
#
#                                                   img  \
# 56  https://play-lh.googleusercontent.com/mnKXlP-7...
# 51  https://play-lh.googleusercontent.com/-YuT-Gxy...
# 53  https://play-lh.googleusercontent.com/XfBF0dWM...
# 57  https://play-lh.googleusercontent.com/UDUU738X...
# 59  https://play-lh.googleusercontent.com/3YUFiVZQ...
#
#                                             key_words     score
# 56  ['오링', '올인', '광고', '애니팡', '삭제', '몰아주기', '짜증', ...  3.899818
# 51  ['꽃신', '엽전', '퍼즐', '업데이트', '고무신', '재미', '시간', ...  3.899037
# 53  ['포커', '오링', '업데이트', '복권', '접속', '애니팡', '배팅', ...  3.800640
# 57  ['올인', '상대방', '보너스', '상대', '뒷패', '오링', '조작', '...  3.604092
# 59  ['광고', '대국', '장기', '기물', '접속', '시간', '상대방', '짜...  3.503359

# %%
recommend_movie_list_gt(rev_data, movie_title = '메이플스토리M')
# Out:
#               Unnamed: 0        genre  rating  review_num  \
# 0      아레스 : 라이즈 오브 가디언즈  roleplaying     4.3       23300
# 25                별이되어라!  roleplaying     4.1      240000
# 14               가디언 테일즈  roleplaying     4.1       85300
# 23  더 킹 오브 파이터즈'98 UM온라인  roleplaying     4.1       12000
# 26              몬스터 길들이기  roleplaying     4.0     1480000
#
#                                                   url  \
# 0   https://play.google.com/store/apps/details?id=...
# 25  https://play.google.com/store/apps/details?id=...
# 14  https://play.google.com/store/apps/details?id=...
# 23  https://play.google.com/store/apps/details?id=...
# 26  https://play.google.com/store/apps/details?id=...
#
#                                                   img  \
# 0   https://play-lh.googleusercontent.com/1VHkCAyM...
# 25  https://play-lh.googleusercontent.com/nQAyNjWO...
# 14  https://play-lh.googleusercontent.com/_ie4f3To...
# 23  https://play-lh.googleusercontent.com/L99-rkQZ...
# 26  https://play-lh.googleusercontent.com/8bCmDr8k...
#
#                                             key_words     score
# 0   ['슈트', '발열', '그래픽', 'sf', 'pc', '재미', '아레스', '...  4.289878
# 25  ['세븐나이츠', '리부트', '대장간', '유저', '신화', '복귀', '각성'...  4.099450
# 14  ['스토리', '가테', '패러디', '가디언', '도트', '캐릭터', '퍼즐',...  4.098458
# 23  ['태연', '마법', '캐릭터', '검마', '그래픽', '업데이트', 'ost'...  4.089449
# 26  ['유저', '퍼스트', '별되', '업데이트', '복귀', '퍼임', '인피니티'...  3.999947

# %%
recommend_movie_list_kc(rev_data, movie_title = '오목')
# Out:
#    Unnamed: 0   genre  rating  review_num  \
# 86        애니팡  puzzle     4.0      201000
# 56     애니팡 맞고   board     3.9      128000
# 85    애니팡 사천성  puzzle     3.8      355000
# 55      바둑2.0   board     3.5        1140
# 77     프렌즈사천성  puzzle     3.6      110000
#
#                                                   url  \
# 86  https://play.google.com/store/apps/details?id=...
# 56  https://play.google.com/store/apps/details?id=...
# 85  https://play.google.com/store/apps/details?id=...
# 55  https://play.google.com/store/apps/details?id=...
# 77  https://play.google.com/store/apps/details?id=...
#
#                                                   img  \
# 86  https://play-lh.googleusercontent.com/Ens0TL2o...
# 56  https://play-lh.googleusercontent.com/mnKXlP-7...
# 85  https://play-lh.googleusercontent.com/dP2SFJpV...
# 55  https://play-lh.googleusercontent.com/Uv7RDIyA...
# 77  https://playgame-img.kakaogames.com/production...
#
#                                             key_words     score
# 86  ['애니팡', '토파즈', '광고', '삭제', '아이템', '접속', '설치', ...  3.999614
# 56  ['오링', '올인', '광고', '애니팡', '삭제', '몰아주기', '짜증', ...  3.899818
# 85  ['광고', '사천성', '딸기', '업데이트', '접속', '오션', '페리', ...  3.800088
# 55  ['바둑', '계가', '대국', '형세', '초읽기', '급수', '타이젬', '...  3.615515
# 77  ['오류', '하트', '사천성', '인터넷', '접속', '시간', '광고', '...  3.601268

# %%
recommend_movie_list_kt(rev_data, movie_title = '애니팡')
# Out:
#     Unnamed: 0   genre  rating  review_num  \
# 72  스누피 틀린그림찾기  puzzle     4.1       40200
# 84        애니팡2  puzzle     4.0     1000000
# 79        프렌즈팝  puzzle     4.0      161000
# 56      애니팡 맞고   board     3.9      128000
# 76        애니팡3  puzzle     3.8      202000
#
#                                                   url  \
# 72  https://play.google.com/store/apps/details?id=...
# 84  https://play.google.com/store/apps/details?id=...
# 79  https://play.google.com/store/apps/details?id=...
# 56  https://play.google.com/store/apps/details?id=...
# 76  https://play.google.com/store/apps/details?id=...
#
#                                                   img  \
# 72  https://play-lh.googleusercontent.com/NC46WYbG...
# 84  https://play-lh.googleusercontent.com/36p2tjeC...
# 79  https://play-lh.googleusercontent.com/x0XsV7vh...
# 56  https://play-lh.googleusercontent.com/mnKXlP-7...
# 76  https://playgame-img.kakaogames.com/production...
#
#                                             key_words     score
# 72  ['광고', '스누피', '그림', '시간', '스테이지', '캐릭터', '짜증',...  4.096752
# 84  ['광고', '애니팡', '업데이트', '스테이지', '시작', '하트', '아이템...  3.999922
# 79  ['프렌즈', '업데이트', '광고', '플레이', '아이템', '크라운', '합성...  3.999518
# 56  ['오링', '올인', '광고', '애니팡', '삭제', '몰아주기', '짜증', ...  3.899818
# 76  ['광고', '애니팡', '하트', '업데이트', '아이템', '스테이지', '시작...  3.800154
